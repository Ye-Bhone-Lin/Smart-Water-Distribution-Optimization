# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, IsolationForest
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, mean_squared_error, r2_score
import joblib

# %%
import os 

os.chdir('/Users/yebhonelin/Documents/github/Smart-Water-Distribution-Optimization/water_pump_maintenance/data')

# %%
df = pd.read_csv(os.getcwd() + "/sensor.csv")   
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (220320, 55)
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# ...

# %%
print(df.info())
print(df.isna().sum().sort_values(ascending=False).head(15))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220320 entries, 0 to 220319
# Data columns (total 55 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      220320 non-null  int64
#  1   timestamp       220320 non-null  object
#  2   sensor_00       210112 non-null  float64
#  3   sensor_01       219951 non-null  float64
#  4   sensor_02       220301 non-null  float64
#  5   sensor_03       220301 non-null  float64
#  6   sensor_04       220301 non-null  float64
#  7   sensor_05       220301 non-null  float64
#  8   sensor_06       215522 non-null  float64
#  9   sensor_07       214869 non-null  float64
#  10  sensor_08       215213 non-null  float64
#  11  sensor_09       215725 non-null  float64
#  12  sensor_10       220301 non-null  float64
#  13  sensor_11       220301 non-null  float64
#  14  sensor_12       220301 non-null  float64
#  15  sensor_13       220301 non-null  float64
# ...

# %%
df[df.columns[2:6]].plot(subplots=True, figsize=(12,6), title="Sample sensors")
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
time_cols = [c for c in df.columns if "time" in c.lower() or "date" in c.lower()]
drop_cols = [c for c in df.columns if c.lower().startswith("unnamed")]
df = df.drop(columns=drop_cols, errors="ignore")

# %%
df
# Out:
#                   timestamp  sensor_00  sensor_01  sensor_02  sensor_03  \
# 0       2018-04-01 00:00:00   2.465394   47.09201  53.211800  46.310760
# 1       2018-04-01 00:01:00   2.465394   47.09201  53.211800  46.310760
# 2       2018-04-01 00:02:00   2.444734   47.35243  53.211800  46.397570
# 3       2018-04-01 00:03:00   2.460474   47.09201  53.168400  46.397568
# 4       2018-04-01 00:04:00   2.445718   47.13541  53.211800  46.397568
# ...                     ...        ...        ...        ...        ...
# 220315  2018-08-31 23:55:00   2.407350   47.69965  50.520830  43.142361
# 220316  2018-08-31 23:56:00   2.400463   47.69965  50.564240  43.142361
# 220317  2018-08-31 23:57:00   2.396528   47.69965  50.520830  43.142361
# 220318  2018-08-31 23:58:00   2.406366   47.69965  50.520832  43.142361
# 220319  2018-08-31 23:59:00   2.396528   47.69965  50.520832  43.142361
#
#          sensor_04  sensor_05  sensor_06  sensor_07  sensor_08  ...  \
# ...

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
numeric_cols
# Out:
# ['sensor_00',
#  'sensor_01',
#  'sensor_02',
#  'sensor_03',
#  'sensor_04',
#  'sensor_05',
#  'sensor_06',
#  'sensor_07',
#  'sensor_08',
#  'sensor_09',
#  'sensor_10',
#  'sensor_11',
#  'sensor_12',
#  'sensor_13',
#  'sensor_14',
#  'sensor_15',
#  'sensor_16',
#  'sensor_17',
#  'sensor_18',
#  'sensor_19',
#  'sensor_20',
#  'sensor_21',
#  'sensor_22',
#  'sensor_23',
#  'sensor_24',
#  'sensor_25',
#  'sensor_26',
#  'sensor_27',
#  'sensor_28',
#  'sensor_29',
#  'sensor_30',
#  'sensor_31',
#  'sensor_32',
#  'sensor_33',
#  'sensor_34',
#  'sensor_35',
#  'sensor_36',
#  'sensor_37',
#  'sensor_38',
#  'sensor_39',
#  'sensor_40',
#  'sensor_41',
#  'sensor_42',
#  'sensor_43',
#  'sensor_44',
#  'sensor_45',
#  'sensor_46',
#  'sensor_47',
#  'sensor_48',
#  'sensor_49',
#  'sensor_50',
#  'sensor_51']

# %%
X = df[numeric_cols].copy()
if target and target in X.columns:
    X = X.drop(columns=[target])

# %%
X = X.replace([np.inf,-np.inf], np.nan)
imputer = SimpleImputer(strategy="median")
X_imputed = imputer.fit_transform(X)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)
# Out:
# /Users/yebhonelin/.local/share/virtualenvs/Smart-Water-Distribution-Optimization-WOOrJqZl/lib/python3.10/site-packages/sklearn/impute/_base.py:653: UserWarning: Skipping features without any observed values: ['sensor_15']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(

# %%
y_raw = df[target]
y_raw
# Out:
# 0         NORMAL
# 1         NORMAL
# 2         NORMAL
# 3         NORMAL
# 4         NORMAL
#            ...
# 220315    NORMAL
# 220316    NORMAL
# 220317    NORMAL
# 220318    NORMAL
# 220319    NORMAL
# Name: machine_status, Length: 220320, dtype: object

# %%
y_raw.value_counts()
# Out:
# machine_status
# NORMAL        205836
# RECOVERING     14477
# BROKEN             7
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smote=SMOTE(sampling_strategy='minority') 
x,y=smote.fit_resample(X_scaled,y_raw)
y.value_counts()
# Out:
# machine_status
# NORMAL        205836
# BROKEN        205836
# RECOVERING     14477
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42, stratify=y)
print("Train shape:", X_train.shape, y_train.shape)
# Out:
# Train shape: (319611, 51) (319611,)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42).fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       BROKEN       1.00      1.00      1.00     51460
#       NORMAL       1.00      1.00      1.00     51459
#   RECOVERING       1.00      1.00      1.00      3619
#
#     accuracy                           1.00    106538
#    macro avg       1.00      1.00      1.00    106538
# weighted avg       1.00      1.00      1.00    106538

# %%
import pickle 

pickle.dump(model, open('rf_model.pkl', 'wb'))
