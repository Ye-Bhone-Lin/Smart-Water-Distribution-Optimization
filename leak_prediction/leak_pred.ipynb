# %% [markdown]
# ### UCI Dataset

# %%
import os

os.getcwd()
# Out:
# '/Users/yebhonelin/Documents/github/Smart-Water-Distribution-Optimization/leak_prediction'

# %%
os.chdir("/Users/yebhonelin/Documents/github/Smart-Water-Distribution-Optimization/leak_prediction/data")

# %%
import pandas as pd

columns = [
    "date", "Q-E", "Z-V", "Q-V", "N-V", "P-V", "D-E", "O-E", "DB-E", "S-E", "SS-E", "D-S",
    "PH-E", "DB-S", "SS-S", "D-D", "PH-D", "DB-D", "SS-D", "D-R", "PH-R", "DB-R", "SS-R",
    "D-I", "E-I", "S-I", "SS-I", "D-O", "PH-O", "DB-O", "SS-O", "P", "D", "PH", "DB",
    "SS", "RD-DB", "RD-SS", "class"
]

df = pd.read_csv(os.getcwd()+"/water-treatment.data", names=columns, na_values="?")

df.head()
# Out:
#        date      Q-E  Z-V  Q-V    N-V    P-V    D-E   O-E  DB-E   S-E  ...  \
# 0  D-1/3/90  44101.0  1.5  7.8    NaN  407.0  166.0  66.3   4.5  2110  ...
# 1  D-2/3/90  39024.0  3.0  7.7    NaN  443.0  214.0  69.2   6.5  2660  ...
# 2  D-4/3/90  32229.0  5.0  7.6    NaN  528.0  186.0  69.9   3.4  1666  ...
# 3  D-5/3/90  35023.0  3.5  7.9  205.0  588.0  192.0  65.6   4.5  2430  ...
# 4  D-6/3/90  36924.0  1.5  8.0  242.0  496.0  176.0  64.8   4.0  2110  ...
#
#      DB-O  SS-O     P     D    PH    DB    SS  RD-DB  RD-SS  class
# 0  2000.0   NaN  58.8  95.5   NaN  70.0   NaN   79.4   87.3   99.6
# 1  2590.0   NaN  60.7  94.8   NaN  80.8   NaN   79.5   92.1  100.0
# 2  1888.0   NaN  58.2  95.6   NaN  52.9   NaN   75.8   88.7   98.5
# 3  1840.0  33.1  64.2  95.3  87.3  72.3  90.2   82.3   89.6  100.0
# 4  2120.0   NaN  62.7  95.6   NaN  71.0  92.1   78.2   87.5   99.5
#
# [5 rows x 39 columns]

# %%
df['class'].unique()
# Out:
# array([ 99.6, 100. ,  98.5,  99.5,  99. ,  99.4,  36.4,  42.9,  95.4,
#         99.2,  99.8,  98.6,  99.3,  96.2,  94.3,  98.8,  99.9,  98.9,
#         98.4,  98.1,   nan,  99.1,  98.2,  99.7,  91.7,  95.7,  97.5,
#         97.8,  92.3,  95. ,  57.1,  88.9,  96.7,  98.3,  98.7,  96. ,
#         85.7,  98. ,  84.6,  95.5,  95.6])

# %%
df.head()
# Out:
#        date      Q-E  Z-V  Q-V    N-V    P-V    D-E   O-E  DB-E   S-E  ...  \
# 0  D-1/3/90  44101.0  1.5  7.8    NaN  407.0  166.0  66.3   4.5  2110  ...
# 1  D-2/3/90  39024.0  3.0  7.7    NaN  443.0  214.0  69.2   6.5  2660  ...
# 2  D-4/3/90  32229.0  5.0  7.6    NaN  528.0  186.0  69.9   3.4  1666  ...
# 3  D-5/3/90  35023.0  3.5  7.9  205.0  588.0  192.0  65.6   4.5  2430  ...
# 4  D-6/3/90  36924.0  1.5  8.0  242.0  496.0  176.0  64.8   4.0  2110  ...
#
#      DB-O  SS-O     P     D    PH    DB    SS  RD-DB  RD-SS  class
# 0  2000.0   NaN  58.8  95.5   NaN  70.0   NaN   79.4   87.3   99.6
# 1  2590.0   NaN  60.7  94.8   NaN  80.8   NaN   79.5   92.1  100.0
# 2  1888.0   NaN  58.2  95.6   NaN  52.9   NaN   75.8   88.7   98.5
# 3  1840.0  33.1  64.2  95.3  87.3  72.3  90.2   82.3   89.6  100.0
# 4  2120.0   NaN  62.7  95.6   NaN  71.0  92.1   78.2   87.5   99.5
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527 entries, 0 to 526
# Data columns (total 39 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    527 non-null    object
#  1   Q-E     509 non-null    float64
#  2   Z-V     524 non-null    float64
#  3   Q-V     527 non-null    float64
#  4   N-V     504 non-null    float64
#  5   P-V     521 non-null    float64
#  6   D-E     526 non-null    float64
#  7   O-E     516 non-null    float64
#  8   DB-E    502 non-null    float64
#  9   S-E     527 non-null    int64
#  10  SS-E    527 non-null    float64
#  11  D-S     487 non-null    float64
#  12  PH-E    527 non-null    int64
#  13  DB-S    516 non-null    float64
#  14  SS-S    503 non-null    float64
#  15  D-D     527 non-null    int64
#  16  PH-D    527 non-null    float64
#  17  DB-D    499 non-null    float64
#  18  SS-D    518 non-null    float64
#  19  D-R     525 non-null    float64
#  20  PH-R    514 non-null    float64
#  21  DB-R    502 non-null    float64
#  22  SS-R    527 non-null    int64
#  23  D-I     526 non-null    float64
#  24  E-I     504 non-null    float64
#  25  S-I     509 non-null    float64
#  26  SS-I    522 non-null    float64
#  27  D-O     510 non-null    float64
#  28  PH-O    499 non-null    float64
#  29  DB-O    526 non-null    float64
#  30  SS-O    465 non-null    float64
#  31  P       523 non-null    float64
#  32  D       500 non-null    float64
#  33  PH      487 non-null    float64
#  34  DB      501 non-null    float64
#  35  SS      491 non-null    float64
#  36  RD-DB   502 non-null    float64
#  37  RD-SS   519 non-null    float64
#  38  class   496 non-null    float64
# dtypes: float64(34), int64(4), object(1)
# memory usage: 160.7+ KB

# %%
df.describe()
# Out:
#                 Q-E         Z-V         Q-V         N-V         P-V  \
# count    509.000000  524.000000  527.000000  504.000000  521.000000
# mean   37226.567780    2.359065    7.810057  188.714286  406.898273
# std     6635.999806    2.749509    0.246175   62.062831  120.362974
# min    10050.000000    0.100000    6.900000   31.000000   81.000000
# 25%    32888.000000    0.900000    7.600000  146.750000  325.000000
# 50%    35990.000000    1.500000    7.800000  182.500000  400.000000
# 75%    41372.000000    3.000000    8.000000  223.000000  478.000000
# max    60081.000000   33.500000    8.700000  438.000000  941.000000
#
#                D-E         O-E        DB-E          S-E        SS-E  ...  \
# count   526.000000  516.000000  502.000000   527.000000  527.000000  ...
# mean    227.444867   61.393217    4.593825  1478.620493    7.829981  ...
# std     135.940589   12.415264    2.743947   394.898019    0.226925  ...
# min      98.000000   13.200000    0.400000   651.000000    7.300000  ...
# 25%     170.000000   55.700000    3.100000  1201.000000    7.700000  ...
# 50%     196.000000   64.300000    4.500000  1406.000000    7.800000  ...
# 75%     242.000000   69.725000    5.500000  1672.000000    8.000000  ...
# max    2008.000000   85.000000   36.000000  3230.000000    8.500000  ...
#
#               DB-O        SS-O           P           D          PH  \
# count   526.000000  465.000000  523.000000  500.000000  487.000000
# mean   1494.817490   39.085806   58.518738   90.554200   83.448049
# std     387.906161   14.792976   12.802547    8.944776    8.804256
# min     683.000000    0.600000    5.300000    7.700000    8.200000
# 25%    1234.500000   29.300000   50.550000   88.600000   81.400000
# 50%    1432.000000   39.600000   59.500000   93.300000   85.400000
# 75%    1692.250000   49.200000   66.900000   96.000000   87.900000
# max    3950.000000   79.100000   96.100000  100.000000   94.700000
#
#                DB          SS       RD-DB       RD-SS       class
# count  501.000000  491.000000  502.000000  519.000000  496.000000
# mean    67.817365   89.013646   77.856574   88.963391   99.086290
# std     11.617612    7.027651    8.888932    8.221612    4.457165
# min      1.400000   19.600000   19.200000   10.300000   36.400000
# 25%     63.100000   87.600000   74.000000   87.600000   99.300000
# 50%     69.900000   90.200000   79.150000   90.700000   99.700000
# 75%     75.300000   92.450000   83.400000   93.100000  100.000000
# max     96.800000   97.000000   98.100000   99.400000  100.000000
#
# [8 rows x 38 columns]

# %%
df.isnull().sum()
# Out:
# date      0
# Q-E      18
# Z-V       3
# Q-V       0
# N-V      23
# P-V       6
# D-E       1
# O-E      11
# DB-E     25
# S-E       0
# SS-E      0
# D-S      40
# PH-E      0
# DB-S     11
# SS-S     24
# D-D       0
# PH-D      0
# DB-D     28
# SS-D      9
# D-R       2
# PH-R     13
# DB-R     25
# SS-R      0
# D-I       1
# E-I      23
# S-I      18
# SS-I      5
# D-O      17
# PH-O     28
# DB-O      1
# SS-O     62
# P         4
# D        27
# PH       40
# DB       26
# SS       36
# RD-DB    25
# RD-SS     8
# class    31
# dtype: int64

# %%
df.shape
# Out:
# (527, 39)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Q-E'}>, <Axes: title={'center': 'Z-V'}>,
#         <Axes: title={'center': 'Q-V'}>, <Axes: title={'center': 'N-V'}>,
#         <Axes: title={'center': 'P-V'}>, <Axes: title={'center': 'D-E'}>],
#        [<Axes: title={'center': 'O-E'}>,
#         <Axes: title={'center': 'DB-E'}>,
#         <Axes: title={'center': 'S-E'}>,
#         <Axes: title={'center': 'SS-E'}>,
#         <Axes: title={'center': 'D-S'}>,
#         <Axes: title={'center': 'PH-E'}>],
#        [<Axes: title={'center': 'DB-S'}>,
#         <Axes: title={'center': 'SS-S'}>,
#         <Axes: title={'center': 'D-D'}>,
#         <Axes: title={'center': 'PH-D'}>,
#         <Axes: title={'center': 'DB-D'}>,
#         <Axes: title={'center': 'SS-D'}>],
#        [<Axes: title={'center': 'D-R'}>,
#         <Axes: title={'center': 'PH-R'}>,
#         <Axes: title={'center': 'DB-R'}>,
#         <Axes: title={'center': 'SS-R'}>,
#         <Axes: title={'center': 'D-I'}>, <Axes: title={'center': 'E-I'}>],
#        [<Axes: title={'center': 'S-I'}>,
#         <Axes: title={'center': 'SS-I'}>,
#         <Axes: title={'center': 'D-O'}>,
#         <Axes: title={'center': 'PH-O'}>,
#         <Axes: title={'center': 'DB-O'}>,
#         <Axes: title={'center': 'SS-O'}>],
#        [<Axes: title={'center': 'P'}>, <Axes: title={'center': 'D'}>,
#         <Axes: title={'center': 'PH'}>, <Axes: title={'center': 'DB'}>,
#         <Axes: title={'center': 'SS'}>,
#         <Axes: title={'center': 'RD-DB'}>],
#        [<Axes: title={'center': 'RD-SS'}>,
#         <Axes: title={'center': 'class'}>, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
from scipy.stats import skew

num_cols = df.select_dtypes(include=['float64','int64']).columns

skewness = df[num_cols].apply(lambda x: skew(x.dropna()))
print(skewness)
# Out:
# Q-E       0.470820
# Z-V       4.697383
# Q-V       0.141932
# N-V       0.781822
# P-V       0.579779
# D-E       6.632060
# O-E      -1.127123
# DB-E      5.394464
# S-E       0.901496
# SS-E      0.248110
# D-S       0.906204
# PH-E      5.388570
# DB-S     -1.028333
# SS-S      5.687508
# D-D       0.895695
# PH-D      0.037476
# DB-D      0.279879
# SS-D      0.047812
# D-R       1.814723
# PH-R     -1.016615
# DB-R      3.393642
# SS-R      0.857490
# D-I       2.022065
# E-I      11.438711
# S-I       2.411584
# SS-I      6.344188
# D-O      -0.887090
# PH-O     13.859713
# DB-O      1.223981
# SS-O     -0.103771
# P        -0.361674
# D        -3.307646
# PH       -4.688443
# DB       -1.477208
# SS       -5.588266
# RD-DB    -1.795609
# RD-SS    -4.552596
# class   -11.539600
# dtype: float64

# %%
for col in num_cols:
    col_skew = skew(df[col].dropna())
    if abs(col_skew) < 0.5:  # normal-ish
        df[col].fillna(df[col].mean(), inplace=True)
    else:  # skewed
        df[col].fillna(df[col].median(), inplace=True)
# Out:
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /var/folders/8m/yr0_n24x0_730_d3f_9sp1th0000gn/T/ipykernel_20533/2141609133.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)

# %% [markdown]
# ##### How i solved the nan values. I visualized the Histogram and check the data behaviour whether normal distribution or left or right skewed. If the data behaviour has a right or left-skewed i chose medium instead of mean. If the data is normal distribution, i chose mean method. For this dataset, i didnt decide to drop the nan values because of the lack of data.

# %%
df.isnull().sum()
# Out:
# date     0
# Q-E      0
# Z-V      0
# Q-V      0
# N-V      0
# P-V      0
# D-E      0
# O-E      0
# DB-E     0
# S-E      0
# SS-E     0
# D-S      0
# PH-E     0
# DB-S     0
# SS-S     0
# D-D      0
# PH-D     0
# DB-D     0
# SS-D     0
# D-R      0
# PH-R     0
# DB-R     0
# SS-R     0
# D-I      0
# E-I      0
# S-I      0
# SS-I     0
# D-O      0
# PH-O     0
# DB-O     0
# SS-O     0
# P        0
# D        0
# PH       0
# DB       0
# SS       0
# RD-DB    0
# RD-SS    0
# class    0
# dtype: int64

# %%
df[df['class'] >= 99]
# Out:
#           date      Q-E   Z-V  Q-V    N-V    P-V    D-E   O-E  DB-E   S-E  \
# 0     D-1/3/90  44101.0  1.50  7.8  182.5  407.0  166.0  66.3   4.5  2110
# 1     D-2/3/90  39024.0  3.00  7.7  182.5  443.0  214.0  69.2   6.5  2660
# 3     D-5/3/90  35023.0  3.50  7.9  205.0  588.0  192.0  65.6   4.5  2430
# 4     D-6/3/90  36924.0  1.50  8.0  242.0  496.0  176.0  64.8   4.0  2110
# 5     D-7/3/90  38572.0  3.00  7.8  202.0  372.0  186.0  68.8   4.5  1644
# ..         ...      ...   ...  ...    ...    ...    ...   ...   ...   ...
# 522  D-26/8/91  32723.0  0.16  7.7   93.0  252.0  176.0  56.8   2.3   894
# 523  D-27/8/91  33535.0  0.32  7.8  192.0  346.0  172.0  68.6   4.0   988
# 524  D-28/8/91  32922.0  0.30  7.4  139.0  367.0  180.0  64.4   3.0  1060
# 525  D-29/8/91  32190.0  0.30  7.3  200.0  545.0  258.0  65.1   4.0  1260
# 526  D-30/8/91  30488.0  0.21  7.5  152.0  300.0  132.0  69.7   4.5  1073
#
#      ...    DB-O       SS-O     P     D    PH    DB    SS  RD-DB  RD-SS  class
# 0    ...  2000.0  39.085806  58.8  95.5  85.4  70.0  90.2   79.4   87.3   99.6
# 1    ...  2590.0  39.085806  60.7  94.8  85.4  80.8  90.2   79.5   92.1  100.0
# 3    ...  1840.0  33.100000  64.2  95.3  87.3  72.3  90.2   82.3   89.6  100.0
# 4    ...  2120.0  39.085806  62.7  95.6  85.4  71.0  92.1   78.2   87.5   99.5
# 5    ...  1764.0  39.085806  59.7  96.5  86.7  78.3  90.1   73.1   84.9  100.0
# ..   ...     ...        ...   ...   ...   ...   ...   ...    ...    ...    ...
# 522  ...   942.0  39.085806  62.3  93.3  69.8  75.9  79.6   78.6   96.6   99.6
# 523  ...   950.0  39.085806  58.3  97.8  83.0  59.1  91.1   74.6   90.7  100.0
# 524  ...  1136.0  39.085806  65.0  97.1  76.2  66.4  82.0   77.1   88.9   99.0
# 525  ...  1326.0  39.800000  65.9  97.1  81.7  70.9  89.5   87.0   89.5   99.8
# 526  ...  1224.0  39.085806  69.5  93.3  81.7  76.4  90.2   81.7   86.4   99.7
#
# [461 rows x 39 columns]

# %%
import numpy as np

conditions = [
    df['class'] >= 95,
    df['class'] < 95
]

choices = ['Normal','Leak-Suspected']

df['class'] = np.select(conditions, choices, default='Unknown')

# %%
df['class'].value_counts()
# Out:
# class
# Normal            518
# Leak-Suspected      9
# Name: count, dtype: int64

# %%
df
# Out:
#           date      Q-E   Z-V  Q-V    N-V    P-V    D-E   O-E  DB-E   S-E  \
# 0     D-1/3/90  44101.0  1.50  7.8  182.5  407.0  166.0  66.3   4.5  2110
# 1     D-2/3/90  39024.0  3.00  7.7  182.5  443.0  214.0  69.2   6.5  2660
# 2     D-4/3/90  32229.0  5.00  7.6  182.5  528.0  186.0  69.9   3.4  1666
# 3     D-5/3/90  35023.0  3.50  7.9  205.0  588.0  192.0  65.6   4.5  2430
# 4     D-6/3/90  36924.0  1.50  8.0  242.0  496.0  176.0  64.8   4.0  2110
# ..         ...      ...   ...  ...    ...    ...    ...   ...   ...   ...
# 522  D-26/8/91  32723.0  0.16  7.7   93.0  252.0  176.0  56.8   2.3   894
# 523  D-27/8/91  33535.0  0.32  7.8  192.0  346.0  172.0  68.6   4.0   988
# 524  D-28/8/91  32922.0  0.30  7.4  139.0  367.0  180.0  64.4   3.0  1060
# 525  D-29/8/91  32190.0  0.30  7.3  200.0  545.0  258.0  65.1   4.0  1260
# 526  D-30/8/91  30488.0  0.21  7.5  152.0  300.0  132.0  69.7   4.5  1073
#
#      ...    DB-O       SS-O     P     D    PH    DB    SS  RD-DB  RD-SS  \
# 0    ...  2000.0  39.085806  58.8  95.5  85.4  70.0  90.2   79.4   87.3
# 1    ...  2590.0  39.085806  60.7  94.8  85.4  80.8  90.2   79.5   92.1
# 2    ...  1888.0  39.085806  58.2  95.6  85.4  52.9  90.2   75.8   88.7
# 3    ...  1840.0  33.100000  64.2  95.3  87.3  72.3  90.2   82.3   89.6
# 4    ...  2120.0  39.085806  62.7  95.6  85.4  71.0  92.1   78.2   87.5
# ..   ...     ...        ...   ...   ...   ...   ...   ...    ...    ...
# 522  ...   942.0  39.085806  62.3  93.3  69.8  75.9  79.6   78.6   96.6
# 523  ...   950.0  39.085806  58.3  97.8  83.0  59.1  91.1   74.6   90.7
# 524  ...  1136.0  39.085806  65.0  97.1  76.2  66.4  82.0   77.1   88.9
# 525  ...  1326.0  39.800000  65.9  97.1  81.7  70.9  89.5   87.0   89.5
# 526  ...  1224.0  39.085806  69.5  93.3  81.7  76.4  90.2   81.7   86.4
#
#       class
# 0    Normal
# 1    Normal
# 2    Normal
# 3    Normal
# 4    Normal
# ..      ...
# 522  Normal
# 523  Normal
# 524  Normal
# 525  Normal
# 526  Normal
#
# [527 rows x 39 columns]

# %%
import seaborn as sns 

sns.countplot(x='class', data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
x = df.drop(['class','date'], axis=1)
y = df['class']
print(x.shape, y.shape)
# Out:
# (527, 37) (527,)

# %% [markdown]
# ##### we see that the target class is imblanced probably 98% and 2%.

# %%
from imblearn.over_sampling import SMOTE

smote=SMOTE(sampling_strategy='minority') 
x,y=smote.fit_resample(x,y)
y.value_counts()
# Out:
# class
# Normal            518
# Leak-Suspected    518
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (828, 37) (208, 37) (828,) (208,)

# %%
import lightgbm as lgb
import shap

clf = lgb.LGBMClassifier(
    n_estimators=200,
    learning_rate=0.05,
    class_weight='balanced', # handle imbalance in target classes
    random_state=42
)

# %%
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
# Out:
# [LightGBM] [Info] Number of positive: 414, number of negative: 414
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000650 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9269
# [LightGBM] [Info] Number of data points in the train set: 828, number of used features: 37
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
from sklearn.metrics import classification_report, confusion_matrix

print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
# Leak-Suspected       1.00      1.00      1.00       104
#         Normal       1.00      1.00      1.00       104
#
#       accuracy                           1.00       208
#      macro avg       1.00      1.00      1.00       208
#   weighted avg       1.00      1.00      1.00       208
#
# Confusion Matrix:
#  [[104   0]
#  [  0 104]]

# %%
explainer = shap.TreeExplainer(clf)
shap_values = explainer.shap_values(x_test)

shap.summary_plot(shap_values, x_test, plot_type="bar")
# Out:
# /Users/yebhonelin/.local/share/virtualenvs/Smart-Water-Distribution-Optimization-WOOrJqZl/lib/python3.10/site-packages/shap/explainers/_tree.py:583: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn(

# %% [markdown]
# ##### In that case we alredy see that PH-O is the most important feature in this dataset and secondly

# %%
y_train = y_train.map({'Normal':0, 'Leak-Suspected':1})
y_test = y_test.map({'Normal':0, 'Leak-Suspected':1})

# %%
import xgboost as xgb

clf = xgb.XGBClassifier(
    n_estimators=200,
    learning_rate=0.05,
    random_state=42,
    use_label_encoder=False,
    eval_metric="logloss"
)

clf.fit(x_train, y_train)
# Out:
# /Users/yebhonelin/.local/share/virtualenvs/Smart-Water-Distribution-Optimization-WOOrJqZl/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [00:13:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       104
#            1       1.00      0.99      1.00       104
#
#     accuracy                           1.00       208
#    macro avg       1.00      1.00      1.00       208
# weighted avg       1.00      1.00      1.00       208
#
# Confusion Matrix:
#  [[104   0]
#  [  1 103]]

# %%
import pickle 

pickle.dump(clf, open('leak_detection_model.pkl', 'wb'))
